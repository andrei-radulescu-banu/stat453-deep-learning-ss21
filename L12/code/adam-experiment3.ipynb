# %% [markdown]
# <a href="https://colab.research.google.com/github/andrei-radulescu-banu/stat453-deep-learning-ss21/blob/main/L12/code/adam-experiment3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# STAT 453: Deep Learning (Spring 2021)
# Instructor: Sebastian Raschka (sraschka@wisc.edu)
#
# Course website: http://pages.stat.wisc.edu/~sraschka/teaching/stat453-ss2021/
# GitHub repository: https://github.com/rasbt/stat453-deep-learning-ss21
#
# ---

# %%
# !pip install watermark
# !pip install colab-env --upgrade
import colab_env
colab_env.envvar_handler.add_env("CUBLAS_WORKSPACE_CONFIG", ":4096:8", overwrite=True)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: watermark in /usr/local/lib/python3.7/dist-packages (2.3.1)
# Requirement already satisfied: importlib-metadata>=1.4 in /usr/local/lib/python3.7/dist-packages (from watermark) (4.13.0)
# Requirement already satisfied: ipython in /usr/local/lib/python3.7/dist-packages (from watermark) (7.9.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=1.4->watermark) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=1.4->watermark) (3.10.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython->watermark) (4.4.2)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from ipython->watermark) (4.8.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from ipython->watermark) (57.4.0)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from ipython->watermark) (2.0.10)
# Requirement already satisfied: backcall in /usr/local/lib/python3.7/dist-packages (from ipython->watermark) (0.2.0)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.7/dist-packages (from ipython->watermark) (5.1.1)
# Requirement already satisfied: jedi>=0.10 in /usr/local/lib/python3.7/dist-packages (from ipython->watermark) (0.18.1)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython->watermark) (2.6.1)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython->watermark) (0.7.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from jedi>=0.10->ipython->watermark) (0.8.3)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython->watermark) (1.15.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython->watermark) (0.2.5)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect->ipython->watermark) (0.7.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: colab-env in /usr/local/lib/python3.7/dist-packages (0.2.0)
# Requirement already satisfied: python-dotenv<1.0,>=0.10.0 in /usr/local/lib/python3.7/dist-packages (from colab-env) (0.21.0)
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# %load_ext watermark
# %watermark -a 'Sebastian Raschka' -v -p torch
# Out:
# Author: Sebastian Raschka
#
# Python implementation: CPython
# Python version       : 3.7.15
# IPython version      : 7.9.0
#
# torch: 1.12.1+cu113

# %% [markdown]
# # MLP with Dropout

# %% [markdown]
# ## Imports

# %%
# !git clone https://github.com/andrei-radulescu-banu/stat453-deep-learning-ss21.git
# Out:
# fatal: destination path 'stat453-deep-learning-ss21' already exists and is not an empty directory.

# %%
# !ls /content/stat453-deep-learning-ss21/L12/code
# Out:
# adabelief.ipynb       batchsize-64.ipynb    helper_train.py
# adam.ipynb	      helper_dataset.py     __pycache__
# adamW.ipynb	      helper_evaluation.py  scheduler.ipynb
# batchsize-1024.ipynb  helper_plotting.py    sgd-scheduler-momentum.ipynb

# %%
import sys, os
sys.path.append("/content/stat453-deep-learning-ss21/L12/code")

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

# %%
# From local helper files
from helper_evaluation import set_all_seeds, set_deterministic
from helper_train import train_model
from helper_plotting import plot_training_loss, plot_accuracy, show_examples
from helper_dataset import get_dataloaders_mnist

# %% [markdown]
# ## Settings and Dataset

# %%
##########################
### SETTINGS
##########################

RANDOM_SEED = 123
BATCH_SIZE = 256
NUM_HIDDEN_1 = 75
NUM_HIDDEN_2 = 45
NUM_EPOCHS = 100
DEVICE = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
set_all_seeds(RANDOM_SEED)
set_deterministic()

# %%
##########################
### MNIST DATASET
##########################

train_loader, valid_loader, test_loader = get_dataloaders_mnist(
    batch_size=BATCH_SIZE,
    validation_fraction=0.1)

# Checking the dataset
for images, labels in train_loader:  
    print('Image batch dimensions:', images.shape)
    print('Image label dimensions:', labels.shape)
    print('Class labels of 10 examples:', labels[:10])
    break
# Out:
# Image batch dimensions: torch.Size([256, 1, 28, 28])
# Image label dimensions: torch.Size([256])
# Class labels of 10 examples: tensor([4, 5, 8, 9, 9, 4, 9, 9, 3, 9])

# %% [markdown]
# ## Model

# %%
class MultilayerPerceptron(torch.nn.Module):

    def __init__(self, num_features, num_classes, drop_proba, 
                 num_hidden_1, num_hidden_2):
        super().__init__()
        
        self.my_network = torch.nn.Sequential(
            # 1st hidden layer
            torch.nn.Flatten(),
            torch.nn.Linear(num_features, num_hidden_1, bias=False),
            torch.nn.BatchNorm1d(num_hidden_1),
            torch.nn.ReLU(),
            torch.nn.Dropout(0.5),
            # 2nd hidden layer
            torch.nn.Linear(num_hidden_1, num_hidden_2, bias=False),
            torch.nn.BatchNorm1d(num_hidden_2),
            torch.nn.ReLU(),
            torch.nn.Dropout(0.3),
            # output layer
            torch.nn.Linear(num_hidden_2, num_classes)
        )
           
    def forward(self, x):
        logits = self.my_network(x)
        return logits

# %%
torch.manual_seed(RANDOM_SEED)
model = MultilayerPerceptron(num_features=28*28,
                             num_hidden_1=NUM_HIDDEN_1,
                             num_hidden_2=NUM_HIDDEN_2,
                             drop_proba=0.5,
                             num_classes=10)
model = model.to(DEVICE)

optimizer = torch.optim.Adam(model.parameters(), lr=0.005)

minibatch_loss_list, train_acc_list, valid_acc_list = train_model(
    model=model,
    num_epochs=NUM_EPOCHS,
    train_loader=train_loader,
    valid_loader=valid_loader,
    test_loader=test_loader,
    optimizer=optimizer,
    device=DEVICE,
    logging_interval=100)

plot_training_loss(minibatch_loss_list=minibatch_loss_list,
                   num_epochs=NUM_EPOCHS,
                   iter_per_epoch=len(train_loader),
                   results_dir=None,
                   averaging_iterations=20)
plt.show()

plot_accuracy(train_acc_list=train_acc_list,
              valid_acc_list=valid_acc_list,
              results_dir=None)
plt.ylim([80, 100])
plt.show()
# Out:
# Epoch: 001/100 | Batch 0000/0210 | Loss: 2.3859
# Epoch: 001/100 | Batch 0100/0210 | Loss: 0.4805
# Epoch: 001/100 | Batch 0200/0210 | Loss: 0.4440
# Epoch: 001/100 | Train: 93.69% | Validation: 95.07%
# Time elapsed: 0.18 min
# Epoch: 002/100 | Batch 0000/0210 | Loss: 0.4458
# Epoch: 002/100 | Batch 0100/0210 | Loss: 0.3063
# Epoch: 002/100 | Batch 0200/0210 | Loss: 0.3967
# Epoch: 002/100 | Train: 95.52% | Validation: 96.35%
# Time elapsed: 0.35 min
# Epoch: 003/100 | Batch 0000/0210 | Loss: 0.3934
# Epoch: 003/100 | Batch 0100/0210 | Loss: 0.2613
# Epoch: 003/100 | Batch 0200/0210 | Loss: 0.3276
# Epoch: 003/100 | Train: 95.88% | Validation: 96.22%
# Time elapsed: 0.52 min
# Epoch: 004/100 | Batch 0000/0210 | Loss: 0.2734
# Epoch: 004/100 | Batch 0100/0210 | Loss: 0.3736
# Epoch: 004/100 | Batch 0200/0210 | Loss: 0.2961
# Epoch: 004/100 | Train: 96.43% | Validation: 96.73%
# Time elapsed: 0.69 min
# Epoch: 005/100 | Batch 0000/0210 | Loss: 0.2352
# Epoch: 005/100 | Batch 0100/0210 | Loss: 0.2915
# Epoch: 005/100 | Batch 0200/0210 | Loss: 0.2384
# Epoch: 005/100 | Train: 96.77% | Validation: 97.28%
# Time elapsed: 0.86 min
# Epoch: 006/100 | Batch 0000/0210 | Loss: 0.2076
# Epoch: 006/100 | Batch 0100/0210 | Loss: 0.3056
# Epoch: 006/100 | Batch 0200/0210 | Loss: 0.2950
# Epoch: 006/100 | Train: 96.74% | Validation: 97.05%
# Time elapsed: 1.03 min
# Epoch: 007/100 | Batch 0000/0210 | Loss: 0.2439
# Epoch: 007/100 | Batch 0100/0210 | Loss: 0.2202
# Epoch: 007/100 | Batch 0200/0210 | Loss: 0.2106
# Epoch: 007/100 | Train: 97.06% | Validation: 97.08%
# Time elapsed: 1.19 min
# Epoch: 008/100 | Batch 0000/0210 | Loss: 0.2491
# Epoch: 008/100 | Batch 0100/0210 | Loss: 0.2280
# Epoch: 008/100 | Batch 0200/0210 | Loss: 0.1684
# Epoch: 008/100 | Train: 97.17% | Validation: 97.15%
# Time elapsed: 1.36 min
# Epoch: 009/100 | Batch 0000/0210 | Loss: 0.2792
# Epoch: 009/100 | Batch 0100/0210 | Loss: 0.1934
# Epoch: 009/100 | Batch 0200/0210 | Loss: 0.2389
# Epoch: 009/100 | Train: 97.30% | Validation: 97.17%
# Time elapsed: 1.52 min
# Epoch: 010/100 | Batch 0000/0210 | Loss: 0.2461
# Epoch: 010/100 | Batch 0100/0210 | Loss: 0.3652
# Epoch: 010/100 | Batch 0200/0210 | Loss: 0.1988
# Epoch: 010/100 | Train: 97.37% | Validation: 97.15%
# Time elapsed: 1.69 min
# Epoch: 011/100 | Batch 0000/0210 | Loss: 0.1719
# Epoch: 011/100 | Batch 0100/0210 | Loss: 0.1744
# Epoch: 011/100 | Batch 0200/0210 | Loss: 0.1768
# Epoch: 011/100 | Train: 97.47% | Validation: 97.12%
# Time elapsed: 1.86 min
# Epoch: 012/100 | Batch 0000/0210 | Loss: 0.3035
# Epoch: 012/100 | Batch 0100/0210 | Loss: 0.2182
# Epoch: 012/100 | Batch 0200/0210 | Loss: 0.2713
# Epoch: 012/100 | Train: 97.66% | Validation: 97.42%
# Time elapsed: 2.02 min
# Epoch: 013/100 | Batch 0000/0210 | Loss: 0.1468
# Epoch: 013/100 | Batch 0100/0210 | Loss: 0.1793
# Epoch: 013/100 | Batch 0200/0210 | Loss: 0.1809
# Epoch: 013/100 | Train: 97.57% | Validation: 97.32%
# Time elapsed: 2.19 min
# Epoch: 014/100 | Batch 0000/0210 | Loss: 0.2073
# Epoch: 014/100 | Batch 0100/0210 | Loss: 0.2947
# Epoch: 014/100 | Batch 0200/0210 | Loss: 0.2223
# Epoch: 014/100 | Train: 97.68% | Validation: 97.15%
# Time elapsed: 2.38 min
# Epoch: 015/100 | Batch 0000/0210 | Loss: 0.1552
# Epoch: 015/100 | Batch 0100/0210 | Loss: 0.1773
# Epoch: 015/100 | Batch 0200/0210 | Loss: 0.2048
# Epoch: 015/100 | Train: 97.67% | Validation: 97.38%
# Time elapsed: 2.55 min
# Epoch: 016/100 | Batch 0000/0210 | Loss: 0.2133
# Epoch: 016/100 | Batch 0100/0210 | Loss: 0.1615
# Epoch: 016/100 | Batch 0200/0210 | Loss: 0.1752
# Epoch: 016/100 | Train: 97.75% | Validation: 97.33%
# Time elapsed: 2.72 min
# Epoch: 017/100 | Batch 0000/0210 | Loss: 0.1358
# Epoch: 017/100 | Batch 0100/0210 | Loss: 0.1887
# Epoch: 017/100 | Batch 0200/0210 | Loss: 0.2365
# Epoch: 017/100 | Train: 97.92% | Validation: 97.53%
# Time elapsed: 2.88 min
# Epoch: 018/100 | Batch 0000/0210 | Loss: 0.1501
# Epoch: 018/100 | Batch 0100/0210 | Loss: 0.2012
# Epoch: 018/100 | Batch 0200/0210 | Loss: 0.2082
# Epoch: 018/100 | Train: 97.89% | Validation: 97.55%
# Time elapsed: 3.05 min
# Epoch: 019/100 | Batch 0000/0210 | Loss: 0.1076
# Epoch: 019/100 | Batch 0100/0210 | Loss: 0.2103
# Epoch: 019/100 | Batch 0200/0210 | Loss: 0.1584
# Epoch: 019/100 | Train: 97.92% | Validation: 97.52%
# Time elapsed: 3.22 min
# Epoch: 020/100 | Batch 0000/0210 | Loss: 0.2328
# Epoch: 020/100 | Batch 0100/0210 | Loss: 0.2414
# Epoch: 020/100 | Batch 0200/0210 | Loss: 0.2563
# Epoch: 020/100 | Train: 97.98% | Validation: 97.45%
# Time elapsed: 3.39 min
# Epoch: 021/100 | Batch 0000/0210 | Loss: 0.2609
# Epoch: 021/100 | Batch 0100/0210 | Loss: 0.3258
# Epoch: 021/100 | Batch 0200/0210 | Loss: 0.1784
# Epoch: 021/100 | Train: 97.95% | Validation: 97.55%
# Time elapsed: 3.56 min
# Epoch: 022/100 | Batch 0000/0210 | Loss: 0.1831
# Epoch: 022/100 | Batch 0100/0210 | Loss: 0.2387
# Epoch: 022/100 | Batch 0200/0210 | Loss: 0.3324
# Epoch: 022/100 | Train: 98.02% | Validation: 97.70%
# Time elapsed: 3.72 min
# Epoch: 023/100 | Batch 0000/0210 | Loss: 0.2720
# Epoch: 023/100 | Batch 0100/0210 | Loss: 0.1665
# Epoch: 023/100 | Batch 0200/0210 | Loss: 0.1998
# Epoch: 023/100 | Train: 98.00% | Validation: 97.58%
# Time elapsed: 3.90 min
# Epoch: 024/100 | Batch 0000/0210 | Loss: 0.1795
# Epoch: 024/100 | Batch 0100/0210 | Loss: 0.1652
# Epoch: 024/100 | Batch 0200/0210 | Loss: 0.1712
# Epoch: 024/100 | Train: 98.07% | Validation: 97.57%
# Time elapsed: 4.06 min
# Epoch: 025/100 | Batch 0000/0210 | Loss: 0.1783
# Epoch: 025/100 | Batch 0100/0210 | Loss: 0.1333
# Epoch: 025/100 | Batch 0200/0210 | Loss: 0.2882
# Epoch: 025/100 | Train: 98.16% | Validation: 97.45%
# Time elapsed: 4.23 min
# Epoch: 026/100 | Batch 0000/0210 | Loss: 0.1429
# Epoch: 026/100 | Batch 0100/0210 | Loss: 0.1786
# Epoch: 026/100 | Batch 0200/0210 | Loss: 0.1413
# Epoch: 026/100 | Train: 98.25% | Validation: 97.52%
# Time elapsed: 4.40 min
# Epoch: 027/100 | Batch 0000/0210 | Loss: 0.2357
# Epoch: 027/100 | Batch 0100/0210 | Loss: 0.1574
# Epoch: 027/100 | Batch 0200/0210 | Loss: 0.1827
# Epoch: 027/100 | Train: 98.19% | Validation: 97.50%
# Time elapsed: 4.56 min
# Epoch: 028/100 | Batch 0000/0210 | Loss: 0.2339
# Epoch: 028/100 | Batch 0100/0210 | Loss: 0.1521
# Epoch: 028/100 | Batch 0200/0210 | Loss: 0.1999
# Epoch: 028/100 | Train: 98.18% | Validation: 97.58%
# Time elapsed: 4.75 min
# Epoch: 029/100 | Batch 0000/0210 | Loss: 0.2023
# Epoch: 029/100 | Batch 0100/0210 | Loss: 0.2629
# Epoch: 029/100 | Batch 0200/0210 | Loss: 0.1546
# Epoch: 029/100 | Train: 98.24% | Validation: 97.60%
# Time elapsed: 4.92 min
# Epoch: 030/100 | Batch 0000/0210 | Loss: 0.0889
# Epoch: 030/100 | Batch 0100/0210 | Loss: 0.1408
# Epoch: 030/100 | Batch 0200/0210 | Loss: 0.2182
# Epoch: 030/100 | Train: 98.27% | Validation: 97.58%
# Time elapsed: 5.09 min
# Epoch: 031/100 | Batch 0000/0210 | Loss: 0.1474
# Epoch: 031/100 | Batch 0100/0210 | Loss: 0.1819
# Epoch: 031/100 | Batch 0200/0210 | Loss: 0.1307
# Epoch: 031/100 | Train: 98.34% | Validation: 97.33%
# Time elapsed: 5.26 min
# Epoch: 032/100 | Batch 0000/0210 | Loss: 0.1978
# Epoch: 032/100 | Batch 0100/0210 | Loss: 0.1698
# Epoch: 032/100 | Batch 0200/0210 | Loss: 0.1772
# Epoch: 032/100 | Train: 98.31% | Validation: 97.52%
# Time elapsed: 5.42 min
# Epoch: 033/100 | Batch 0000/0210 | Loss: 0.2777
# Epoch: 033/100 | Batch 0100/0210 | Loss: 0.1470
# Epoch: 033/100 | Batch 0200/0210 | Loss: 0.2524
# Epoch: 033/100 | Train: 98.40% | Validation: 97.63%
# Time elapsed: 5.59 min
# Epoch: 034/100 | Batch 0000/0210 | Loss: 0.1338
# Epoch: 034/100 | Batch 0100/0210 | Loss: 0.1652
# Epoch: 034/100 | Batch 0200/0210 | Loss: 0.2215
# Epoch: 034/100 | Train: 98.33% | Validation: 97.37%
# Time elapsed: 5.76 min
# Epoch: 035/100 | Batch 0000/0210 | Loss: 0.1521
# Epoch: 035/100 | Batch 0100/0210 | Loss: 0.2152
# Epoch: 035/100 | Batch 0200/0210 | Loss: 0.1395
# Epoch: 035/100 | Train: 98.41% | Validation: 97.68%
# Time elapsed: 5.93 min
# Epoch: 036/100 | Batch 0000/0210 | Loss: 0.1843
# Epoch: 036/100 | Batch 0100/0210 | Loss: 0.1851
# Epoch: 036/100 | Batch 0200/0210 | Loss: 0.2285
# Epoch: 036/100 | Train: 98.38% | Validation: 97.62%
# Time elapsed: 6.10 min
# Epoch: 037/100 | Batch 0000/0210 | Loss: 0.1566
# Epoch: 037/100 | Batch 0100/0210 | Loss: 0.1474
# Epoch: 037/100 | Batch 0200/0210 | Loss: 0.2572
# Epoch: 037/100 | Train: 98.38% | Validation: 97.72%
# Time elapsed: 6.27 min
# Epoch: 038/100 | Batch 0000/0210 | Loss: 0.1423
# Epoch: 038/100 | Batch 0100/0210 | Loss: 0.1995
# Epoch: 038/100 | Batch 0200/0210 | Loss: 0.2573
# Epoch: 038/100 | Train: 98.45% | Validation: 97.58%
# Time elapsed: 6.43 min
# Epoch: 039/100 | Batch 0000/0210 | Loss: 0.1728
# Epoch: 039/100 | Batch 0100/0210 | Loss: 0.1629
# Epoch: 039/100 | Batch 0200/0210 | Loss: 0.1790
# Epoch: 039/100 | Train: 98.43% | Validation: 97.75%
# Time elapsed: 6.60 min
# Epoch: 040/100 | Batch 0000/0210 | Loss: 0.2375
# Epoch: 040/100 | Batch 0100/0210 | Loss: 0.2475
# Epoch: 040/100 | Batch 0200/0210 | Loss: 0.1608
# Epoch: 040/100 | Train: 98.40% | Validation: 97.50%
# Time elapsed: 6.77 min
# Epoch: 041/100 | Batch 0000/0210 | Loss: 0.2452
# Epoch: 041/100 | Batch 0100/0210 | Loss: 0.2337
# Epoch: 041/100 | Batch 0200/0210 | Loss: 0.1198
# Epoch: 041/100 | Train: 98.43% | Validation: 97.62%
# Time elapsed: 6.94 min
# Epoch: 042/100 | Batch 0000/0210 | Loss: 0.1331
# Epoch: 042/100 | Batch 0100/0210 | Loss: 0.1188
# Epoch: 042/100 | Batch 0200/0210 | Loss: 0.2008
# Epoch: 042/100 | Train: 98.53% | Validation: 97.62%
# Time elapsed: 7.12 min
# Epoch: 043/100 | Batch 0000/0210 | Loss: 0.1895
# Epoch: 043/100 | Batch 0100/0210 | Loss: 0.1933
# Epoch: 043/100 | Batch 0200/0210 | Loss: 0.1129
# Epoch: 043/100 | Train: 98.48% | Validation: 97.62%
# Time elapsed: 7.29 min
# Epoch: 044/100 | Batch 0000/0210 | Loss: 0.1715
# Epoch: 044/100 | Batch 0100/0210 | Loss: 0.1908
# Epoch: 044/100 | Batch 0200/0210 | Loss: 0.1713
# Epoch: 044/100 | Train: 98.50% | Validation: 97.57%
# Time elapsed: 7.46 min
# Epoch: 045/100 | Batch 0000/0210 | Loss: 0.1090
# Epoch: 045/100 | Batch 0100/0210 | Loss: 0.1290
# Epoch: 045/100 | Batch 0200/0210 | Loss: 0.1098
# Epoch: 045/100 | Train: 98.46% | Validation: 97.67%
# Time elapsed: 7.63 min
# Epoch: 046/100 | Batch 0000/0210 | Loss: 0.1454
# Epoch: 046/100 | Batch 0100/0210 | Loss: 0.2418
# Epoch: 046/100 | Batch 0200/0210 | Loss: 0.1196
# Epoch: 046/100 | Train: 98.51% | Validation: 97.63%
# Time elapsed: 7.80 min
# Epoch: 047/100 | Batch 0000/0210 | Loss: 0.1562
# Epoch: 047/100 | Batch 0100/0210 | Loss: 0.2379
# Epoch: 047/100 | Batch 0200/0210 | Loss: 0.1188
# Epoch: 047/100 | Train: 98.47% | Validation: 97.60%
# Time elapsed: 7.97 min
# Epoch: 048/100 | Batch 0000/0210 | Loss: 0.1639
# Epoch: 048/100 | Batch 0100/0210 | Loss: 0.1528
# Epoch: 048/100 | Batch 0200/0210 | Loss: 0.2083
# Epoch: 048/100 | Train: 98.57% | Validation: 97.75%
# Time elapsed: 8.13 min
# Epoch: 049/100 | Batch 0000/0210 | Loss: 0.1941
# Epoch: 049/100 | Batch 0100/0210 | Loss: 0.2349
# Epoch: 049/100 | Batch 0200/0210 | Loss: 0.1860
# Epoch: 049/100 | Train: 98.58% | Validation: 97.63%
# Time elapsed: 8.30 min
# Epoch: 050/100 | Batch 0000/0210 | Loss: 0.1122
# Epoch: 050/100 | Batch 0100/0210 | Loss: 0.2704
# Epoch: 050/100 | Batch 0200/0210 | Loss: 0.1156
# Epoch: 050/100 | Train: 98.57% | Validation: 97.67%
# Time elapsed: 8.46 min
# Epoch: 051/100 | Batch 0000/0210 | Loss: 0.1981
# Epoch: 051/100 | Batch 0100/0210 | Loss: 0.2103
# Epoch: 051/100 | Batch 0200/0210 | Loss: 0.3131
# Epoch: 051/100 | Train: 98.58% | Validation: 97.70%
# Time elapsed: 8.63 min
# Epoch: 052/100 | Batch 0000/0210 | Loss: 0.2034
# Epoch: 052/100 | Batch 0100/0210 | Loss: 0.0838
# Epoch: 052/100 | Batch 0200/0210 | Loss: 0.1464
# Epoch: 052/100 | Train: 98.59% | Validation: 97.53%
# Time elapsed: 8.80 min
# Epoch: 053/100 | Batch 0000/0210 | Loss: 0.1800
# Epoch: 053/100 | Batch 0100/0210 | Loss: 0.1435
# Epoch: 053/100 | Batch 0200/0210 | Loss: 0.1899
# Epoch: 053/100 | Train: 98.67% | Validation: 97.72%
# Time elapsed: 8.97 min
# Epoch: 054/100 | Batch 0000/0210 | Loss: 0.1600
# Epoch: 054/100 | Batch 0100/0210 | Loss: 0.2190
# Epoch: 054/100 | Batch 0200/0210 | Loss: 0.2068
# Epoch: 054/100 | Train: 98.64% | Validation: 97.62%
# Time elapsed: 9.13 min
# Epoch: 055/100 | Batch 0000/0210 | Loss: 0.1611
# Epoch: 055/100 | Batch 0100/0210 | Loss: 0.2003
# Epoch: 055/100 | Batch 0200/0210 | Loss: 0.1641
# Epoch: 055/100 | Train: 98.59% | Validation: 97.73%
# Time elapsed: 9.29 min
# Epoch: 056/100 | Batch 0000/0210 | Loss: 0.1289
# Epoch: 056/100 | Batch 0100/0210 | Loss: 0.1838
# Epoch: 056/100 | Batch 0200/0210 | Loss: 0.1374
# Epoch: 056/100 | Train: 98.63% | Validation: 97.65%
# Time elapsed: 9.47 min
# Epoch: 057/100 | Batch 0000/0210 | Loss: 0.1203
# Epoch: 057/100 | Batch 0100/0210 | Loss: 0.1975
# Epoch: 057/100 | Batch 0200/0210 | Loss: 0.2155
# Epoch: 057/100 | Train: 98.67% | Validation: 97.65%
# Time elapsed: 9.65 min
# Epoch: 058/100 | Batch 0000/0210 | Loss: 0.1726
# Epoch: 058/100 | Batch 0100/0210 | Loss: 0.1401
# Epoch: 058/100 | Batch 0200/0210 | Loss: 0.1739
# Epoch: 058/100 | Train: 98.66% | Validation: 97.60%
# Time elapsed: 9.81 min
# Epoch: 059/100 | Batch 0000/0210 | Loss: 0.1662
# Epoch: 059/100 | Batch 0100/0210 | Loss: 0.1720
# Epoch: 059/100 | Batch 0200/0210 | Loss: 0.1744
# Epoch: 059/100 | Train: 98.60% | Validation: 97.47%
# Time elapsed: 9.98 min
# Epoch: 060/100 | Batch 0000/0210 | Loss: 0.1262
# Epoch: 060/100 | Batch 0100/0210 | Loss: 0.1270
# Epoch: 060/100 | Batch 0200/0210 | Loss: 0.1186
# Epoch: 060/100 | Train: 98.66% | Validation: 97.73%
# Time elapsed: 10.14 min
# Epoch: 061/100 | Batch 0000/0210 | Loss: 0.1647
# Epoch: 061/100 | Batch 0100/0210 | Loss: 0.2189
# Epoch: 061/100 | Batch 0200/0210 | Loss: 0.1868
# Epoch: 061/100 | Train: 98.70% | Validation: 97.58%
# Time elapsed: 10.31 min
# Epoch: 062/100 | Batch 0000/0210 | Loss: 0.1376
# Epoch: 062/100 | Batch 0100/0210 | Loss: 0.1808
# Epoch: 062/100 | Batch 0200/0210 | Loss: 0.1367
# Epoch: 062/100 | Train: 98.71% | Validation: 97.53%
# Time elapsed: 10.47 min
# Epoch: 063/100 | Batch 0000/0210 | Loss: 0.1520
# Epoch: 063/100 | Batch 0100/0210 | Loss: 0.1552
# Epoch: 063/100 | Batch 0200/0210 | Loss: 0.1658
# Epoch: 063/100 | Train: 98.79% | Validation: 97.62%
# Time elapsed: 10.64 min
# Epoch: 064/100 | Batch 0000/0210 | Loss: 0.1266
# Epoch: 064/100 | Batch 0100/0210 | Loss: 0.1386
# Epoch: 064/100 | Batch 0200/0210 | Loss: 0.1623
# Epoch: 064/100 | Train: 98.81% | Validation: 97.62%
# Time elapsed: 10.81 min
# Epoch: 065/100 | Batch 0000/0210 | Loss: 0.1279
# Epoch: 065/100 | Batch 0100/0210 | Loss: 0.1553
# Epoch: 065/100 | Batch 0200/0210 | Loss: 0.1714
# Epoch: 065/100 | Train: 98.82% | Validation: 97.62%
# Time elapsed: 10.97 min
# Epoch: 066/100 | Batch 0000/0210 | Loss: 0.0756
# Epoch: 066/100 | Batch 0100/0210 | Loss: 0.1293
# Epoch: 066/100 | Batch 0200/0210 | Loss: 0.1408
# Epoch: 066/100 | Train: 98.75% | Validation: 97.48%
# Time elapsed: 11.14 min
# Epoch: 067/100 | Batch 0000/0210 | Loss: 0.1910
# Epoch: 067/100 | Batch 0100/0210 | Loss: 0.1538
# Epoch: 067/100 | Batch 0200/0210 | Loss: 0.1174
# Epoch: 067/100 | Train: 98.67% | Validation: 97.58%
# Time elapsed: 11.30 min
# Epoch: 068/100 | Batch 0000/0210 | Loss: 0.1952
# Epoch: 068/100 | Batch 0100/0210 | Loss: 0.1429
# Epoch: 068/100 | Batch 0200/0210 | Loss: 0.1266
# Epoch: 068/100 | Train: 98.76% | Validation: 97.53%
# Time elapsed: 11.47 min
# Epoch: 069/100 | Batch 0000/0210 | Loss: 0.1131
# Epoch: 069/100 | Batch 0100/0210 | Loss: 0.2370
# Epoch: 069/100 | Batch 0200/0210 | Loss: 0.2191
# Epoch: 069/100 | Train: 98.86% | Validation: 97.67%
# Time elapsed: 11.64 min
# Epoch: 070/100 | Batch 0000/0210 | Loss: 0.1301
# Epoch: 070/100 | Batch 0100/0210 | Loss: 0.1551
# Epoch: 070/100 | Batch 0200/0210 | Loss: 0.2023
# Epoch: 070/100 | Train: 98.77% | Validation: 97.68%
# Time elapsed: 11.81 min
# Epoch: 071/100 | Batch 0000/0210 | Loss: 0.1117
# Epoch: 071/100 | Batch 0100/0210 | Loss: 0.1856
# Epoch: 071/100 | Batch 0200/0210 | Loss: 0.1462
# Epoch: 071/100 | Train: 98.77% | Validation: 97.55%
# Time elapsed: 11.99 min
# Epoch: 072/100 | Batch 0000/0210 | Loss: 0.0666
# Epoch: 072/100 | Batch 0100/0210 | Loss: 0.1428
# Epoch: 072/100 | Batch 0200/0210 | Loss: 0.2014
# Epoch: 072/100 | Train: 98.82% | Validation: 97.75%
# Time elapsed: 12.16 min
# Epoch: 073/100 | Batch 0000/0210 | Loss: 0.1377
# Epoch: 073/100 | Batch 0100/0210 | Loss: 0.1752
# Epoch: 073/100 | Batch 0200/0210 | Loss: 0.1766
# Epoch: 073/100 | Train: 98.82% | Validation: 97.60%
# Time elapsed: 12.32 min
# Epoch: 074/100 | Batch 0000/0210 | Loss: 0.0640
# Epoch: 074/100 | Batch 0100/0210 | Loss: 0.1298
# Epoch: 074/100 | Batch 0200/0210 | Loss: 0.1541
# Epoch: 074/100 | Train: 98.81% | Validation: 97.63%
# Time elapsed: 12.49 min
# Epoch: 075/100 | Batch 0000/0210 | Loss: 0.1193
# Epoch: 075/100 | Batch 0100/0210 | Loss: 0.1110
# Epoch: 075/100 | Batch 0200/0210 | Loss: 0.2317
# Epoch: 075/100 | Train: 98.88% | Validation: 97.68%
# Time elapsed: 12.66 min
# Epoch: 076/100 | Batch 0000/0210 | Loss: 0.1535
# Epoch: 076/100 | Batch 0100/0210 | Loss: 0.1637
# Epoch: 076/100 | Batch 0200/0210 | Loss: 0.2095
# Epoch: 076/100 | Train: 98.82% | Validation: 97.65%
# Time elapsed: 12.83 min
# Epoch: 077/100 | Batch 0000/0210 | Loss: 0.1886
# Epoch: 077/100 | Batch 0100/0210 | Loss: 0.0866
# Epoch: 077/100 | Batch 0200/0210 | Loss: 0.1333
# Epoch: 077/100 | Train: 98.88% | Validation: 97.63%
# Time elapsed: 13.00 min
# Epoch: 078/100 | Batch 0000/0210 | Loss: 0.0893
# Epoch: 078/100 | Batch 0100/0210 | Loss: 0.1375
# Epoch: 078/100 | Batch 0200/0210 | Loss: 0.2074
# Epoch: 078/100 | Train: 98.81% | Validation: 97.68%
# Time elapsed: 13.16 min
# Epoch: 079/100 | Batch 0000/0210 | Loss: 0.1904
# Epoch: 079/100 | Batch 0100/0210 | Loss: 0.1368
# Epoch: 079/100 | Batch 0200/0210 | Loss: 0.1245
# Epoch: 079/100 | Train: 98.95% | Validation: 97.70%
# Time elapsed: 13.33 min
# Epoch: 080/100 | Batch 0000/0210 | Loss: 0.2473
# Epoch: 080/100 | Batch 0100/0210 | Loss: 0.2051
# Epoch: 080/100 | Batch 0200/0210 | Loss: 0.1506
# Epoch: 080/100 | Train: 98.87% | Validation: 97.70%
# Time elapsed: 13.49 min
# Epoch: 081/100 | Batch 0000/0210 | Loss: 0.1494
# Epoch: 081/100 | Batch 0100/0210 | Loss: 0.1183
# Epoch: 081/100 | Batch 0200/0210 | Loss: 0.1484
# Epoch: 081/100 | Train: 98.92% | Validation: 97.67%
# Time elapsed: 13.66 min
# Epoch: 082/100 | Batch 0000/0210 | Loss: 0.1067
# Epoch: 082/100 | Batch 0100/0210 | Loss: 0.1356
# Epoch: 082/100 | Batch 0200/0210 | Loss: 0.1548
# Epoch: 082/100 | Train: 98.86% | Validation: 97.67%
# Time elapsed: 13.83 min
# Epoch: 083/100 | Batch 0000/0210 | Loss: 0.1729
# Epoch: 083/100 | Batch 0100/0210 | Loss: 0.1114
# Epoch: 083/100 | Batch 0200/0210 | Loss: 0.1032
# Epoch: 083/100 | Train: 98.92% | Validation: 97.72%
# Time elapsed: 13.99 min
# Epoch: 084/100 | Batch 0000/0210 | Loss: 0.1919
# Epoch: 084/100 | Batch 0100/0210 | Loss: 0.2043
# Epoch: 084/100 | Batch 0200/0210 | Loss: 0.1240
# Epoch: 084/100 | Train: 98.92% | Validation: 97.67%
# Time elapsed: 14.16 min
# Epoch: 085/100 | Batch 0000/0210 | Loss: 0.1564
# Epoch: 085/100 | Batch 0100/0210 | Loss: 0.1239
# Epoch: 085/100 | Batch 0200/0210 | Loss: 0.1670
# Epoch: 085/100 | Train: 98.93% | Validation: 97.55%
# Time elapsed: 14.35 min
# Epoch: 086/100 | Batch 0000/0210 | Loss: 0.1341
# Epoch: 086/100 | Batch 0100/0210 | Loss: 0.1061
# Epoch: 086/100 | Batch 0200/0210 | Loss: 0.1577
# Epoch: 086/100 | Train: 98.95% | Validation: 97.48%
# Time elapsed: 14.51 min
# Epoch: 087/100 | Batch 0000/0210 | Loss: 0.1673
# Epoch: 087/100 | Batch 0100/0210 | Loss: 0.1356
# Epoch: 087/100 | Batch 0200/0210 | Loss: 0.2423
# Epoch: 087/100 | Train: 98.93% | Validation: 97.58%
# Time elapsed: 14.68 min
# Epoch: 088/100 | Batch 0000/0210 | Loss: 0.1044
# Epoch: 088/100 | Batch 0100/0210 | Loss: 0.1272
# Epoch: 088/100 | Batch 0200/0210 | Loss: 0.1148
# Epoch: 088/100 | Train: 98.94% | Validation: 97.63%
# Time elapsed: 14.85 min
# Epoch: 089/100 | Batch 0000/0210 | Loss: 0.1212
# Epoch: 089/100 | Batch 0100/0210 | Loss: 0.1023
# Epoch: 089/100 | Batch 0200/0210 | Loss: 0.2473
# Epoch: 089/100 | Train: 99.01% | Validation: 97.75%
# Time elapsed: 15.01 min
# Epoch: 090/100 | Batch 0000/0210 | Loss: 0.1432
# Epoch: 090/100 | Batch 0100/0210 | Loss: 0.1670
# Epoch: 090/100 | Batch 0200/0210 | Loss: 0.1393
# Epoch: 090/100 | Train: 99.02% | Validation: 97.73%
# Time elapsed: 15.18 min
# Epoch: 091/100 | Batch 0000/0210 | Loss: 0.1520
# Epoch: 091/100 | Batch 0100/0210 | Loss: 0.1278
# Epoch: 091/100 | Batch 0200/0210 | Loss: 0.1798
# Epoch: 091/100 | Train: 98.97% | Validation: 97.68%
# Time elapsed: 15.35 min
# Epoch: 092/100 | Batch 0000/0210 | Loss: 0.1351
# Epoch: 092/100 | Batch 0100/0210 | Loss: 0.1720
# Epoch: 092/100 | Batch 0200/0210 | Loss: 0.1736
# Epoch: 092/100 | Train: 98.97% | Validation: 97.63%
# Time elapsed: 15.51 min
# Epoch: 093/100 | Batch 0000/0210 | Loss: 0.1898
# Epoch: 093/100 | Batch 0100/0210 | Loss: 0.1329
# Epoch: 093/100 | Batch 0200/0210 | Loss: 0.1294
# Epoch: 093/100 | Train: 98.94% | Validation: 97.52%
# Time elapsed: 15.68 min
# Epoch: 094/100 | Batch 0000/0210 | Loss: 0.1002
# Epoch: 094/100 | Batch 0100/0210 | Loss: 0.2210
# Epoch: 094/100 | Batch 0200/0210 | Loss: 0.2539
# Epoch: 094/100 | Train: 98.93% | Validation: 97.53%
# Time elapsed: 15.84 min
# Epoch: 095/100 | Batch 0000/0210 | Loss: 0.1204
# Epoch: 095/100 | Batch 0100/0210 | Loss: 0.1549
# Epoch: 095/100 | Batch 0200/0210 | Loss: 0.1914
# Epoch: 095/100 | Train: 99.03% | Validation: 97.73%
# Time elapsed: 16.01 min
# Epoch: 096/100 | Batch 0000/0210 | Loss: 0.1134
# Epoch: 096/100 | Batch 0100/0210 | Loss: 0.0932
# Epoch: 096/100 | Batch 0200/0210 | Loss: 0.0825
# Epoch: 096/100 | Train: 98.92% | Validation: 97.75%
# Time elapsed: 16.18 min
# Epoch: 097/100 | Batch 0000/0210 | Loss: 0.1540
# Epoch: 097/100 | Batch 0100/0210 | Loss: 0.0727
# Epoch: 097/100 | Batch 0200/0210 | Loss: 0.1171
# Epoch: 097/100 | Train: 99.02% | Validation: 97.73%
# Time elapsed: 16.34 min
# Epoch: 098/100 | Batch 0000/0210 | Loss: 0.1181
# Epoch: 098/100 | Batch 0100/0210 | Loss: 0.1080
# Epoch: 098/100 | Batch 0200/0210 | Loss: 0.1681
# Epoch: 098/100 | Train: 99.05% | Validation: 97.67%
# Time elapsed: 16.51 min
# Epoch: 099/100 | Batch 0000/0210 | Loss: 0.1213
# Epoch: 099/100 | Batch 0100/0210 | Loss: 0.1391
# Epoch: 099/100 | Batch 0200/0210 | Loss: 0.1788
# Epoch: 099/100 | Train: 98.94% | Validation: 97.65%
# Time elapsed: 16.70 min
# Epoch: 100/100 | Batch 0000/0210 | Loss: 0.1229
# Epoch: 100/100 | Batch 0100/0210 | Loss: 0.1593
# Epoch: 100/100 | Batch 0200/0210 | Loss: 0.0986
# Epoch: 100/100 | Train: 98.95% | Validation: 97.65%
# Time elapsed: 16.86 min
# Total Training Time: 16.86 min
# Test accuracy 97.19%
